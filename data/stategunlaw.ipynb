# %%
#Data Cleaning and EDA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math as m



import warnings
warnings.filterwarnings("ignore")

# %%
lawsdf = pd.read_excel("../Capstone/stategunlaw.xlsx")

# %%
lawsdf
# Out:
#         state  year  felony  invcommitment  invoutpatient  danger  \
# 0     Alabama  1991       0              0              0       0
# 1     Alabama  1992       0              0              0       0
# 2     Alabama  1993       0              0              0       0
# 3     Alabama  1994       0              0              0       0
# 4     Alabama  1995       0              0              0       0
# ...       ...   ...     ...            ...            ...     ...
# 1495  Wyoming  2016       1              0              0       0
# 1496  Wyoming  2017       1              0              0       0
# 1497  Wyoming  2018       1              0              0       0
# 1498  Wyoming  2019       1              0              0       0
# 1499  Wyoming  2020       1              0              0       0
#
#       drugmisdemeanor  alctreatment  alcoholism  relinquishment  ...  \
# 0                   0             0           1               0  ...
# ...

# %%
TotalLaws = pd.pivot_table(data= lawsdf, values= 'lawtotal', index ='state', aggfunc = 'mean')
print(TotalLaws)
# Out:
#                  lawtotal
# state
# Alabama         12.166667
# Alaska           5.466667
# Arizona         10.833333
# Arkansas        12.333333
# California      87.633333
# Colorado        18.333333
# Connecticut     67.800000
# Delaware        26.033333
# Florida         21.800000
# Georgia         10.166667
# Hawaii          70.500000
# Idaho            5.166667
# Illinois        57.633333
# Indiana         10.433333
# Iowa            21.533333
# Kansas          10.366667
# Kentucky         6.833333
# Louisiana       10.633333
# Maine            9.933333
# Maryland        51.166667
# Massachusetts   91.833333
# Michigan        23.200000
# Minnesota       31.800000
# Mississippi      7.166667
# Missouri        11.000000
# Montana          4.266667
# Nebraska        21.500000
# Nevada          11.166667
# New Hampshire    9.766667
# New Jersey      61.500000
# New Mexico      10.466667
# New York        57.166667
# North Carolina  26.200000
# North Dakota    12.400000
# ...

# %%
missouri = lawsdf.query("state =='Missouri'")
misslaw = missouri.groupby("year")["alcoholism"].sum().round(2)
misslaw.head()
# Out:
# year
# 1991    1
# 1992    1
# 1993    1
# 1994    1
# 1995    1
# Name: alcoholism, dtype: int64
