# %%
#Data Cleaning and EDA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math as m



import warnings
warnings.filterwarnings("ignore")

# %%
firearms = pd.read_csv("../Capstone/firearmMortatlity.csv")

# %%
firearms
# Out:
#      YEAR STATE  RATE  DEATHS  \
# 0    2021    AL  26.4    1315
# 1    2021    AK  25.2     182
# 2    2021    AZ  18.3    1365
# 3    2021    AR  23.3     698
# 4    2021    CA   9.0    3576
# ..    ...   ...   ...     ...
# 445  2005    VA  11.5     888
# 446  2005    WA   8.8     567
# 447  2005    WV  13.8     261
# 448  2005    WI   8.5     474
# 449  2005    WY  13.4      71
#
#                                                    URL
# 0                /nchs/pressroom/states/alabama/al.htm
# 1                 /nchs/pressroom/states/alaska/ak.htm
# 2                /nchs/pressroom/states/arizona/az.htm
# 3               /nchs/pressroom/states/arkansas/ar.htm
# 4             /nchs/pressroom/states/california/ca.htm
# ..                                                 ...
# 445       /nchs/pressroom/states/virginia/virginia.htm
# 446   /nchs/pressroom/states/washington/washington.htm
# 447  /nchs/pressroom/states/westvirginia/westvirgin...
# ...

# %%
pivot_firearms = pd.pivot_table(firearms,index = 'STATE', values = 'DEATHS', aggfunc ='mean')

# %%
pivot_firearms
# Out:
#             DEATHS
# STATE
# AK      165.111111
# AL     1030.555556
# AR      570.333333
# AZ     1108.000000
# CA     3207.555556
# CO      801.222222
# CT      196.222222
# DE      111.555556
# FL     2688.000000
# GA     1618.777778
# HI       52.222222
# IA      284.555556
# ID      261.777778
# IL     1437.777778
# IN      969.666667
# KS      398.777778
# KY      741.222222
# LA     1022.444444
# MA      243.000000
# MD      726.888889
# ME      148.222222
# MI     1247.666667
# MN      448.111111
# MO     1182.555556
# MS      664.555556
# MT      209.888889
# NC     1422.666667
# ND       94.666667
# NE      177.666667
# NH      130.111111
# NJ      449.555556
# NM      415.555556
# NV      499.000000
# NY      907.777778
# OH     1516.111111
# OK      699.555556
# OR      530.333333
# PA     1585.555556
# RI       46.555556
# SC      907.111111
# SD      106.000000
# TN     1222.333333
# TX     3487.666667
# UT      375.666667
# VA     1032.777778
# VT       71.000000
# ...

# %%
pivot_firearms.plot( kind = 'bar')
plt.ylabel('DEATH')
plt.title('Average Deaths Per State')
plt.legend()
plt.show()

# %%
TotalDeathState = firearms.groupby('STATE')['DEATHS'].sum().round(2)
print(TotalDeathState)
# Out:
# STATE
# AK     1486
# AL     9275
# AR     5133
# AZ     9972
# CA    28868
# CO     7211
# CT     1766
# DE     1004
# FL    24192
# GA    14569
# HI      470
# IA     2561
# ID     2356
# IL    12940
# IN     8727
# KS     3589
# KY     6671
# LA     9202
# MA     2187
# MD     6542
# ME     1334
# MI    11229
# MN     4033
# MO    10643
# MS     5981
# MT     1889
# NC    12804
# ND      852
# NE     1599
# NH     1171
# NJ     4046
# NM     3740
# NV     4491
# NY     8170
# OH    13645
# OK     6296
# OR     4773
# PA    14270
# RI      419
# SC     8164
# SD      954
# TN    11001
# TX    31389
# UT     3381
# VA     9295
# VT      639
# WA     6933
# WI     5574
# WV     2792
# WY     1057
# Name: DEATHS, dtype: int64

# %%
Cali = firearms[firearms.STATE =='CA']

# %%
FL = firearms[firearms.STATE =='FL']

# %%
TX = firearms[firearms.STATE =='TX']

# %%
plt.plot(Cali.YEAR, Cali.DEATHS)
plt.plot(FL.YEAR, FL.DEATHS)
plt.plot(TX.YEAR, TX.DEATHS)

plt.legend(['California', 'Florida', 'Texas'])
plt.xlabel('YEAR')
plt.ylabel('DEATHS')
plt.show()
